# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd
import seaborn as sns

# %%
alamat = "https://pokemondb.net/pokedex/all"
safeAdd = Request(alamat, headers={'User-Agent': 'Mozilla/5.0'})
html = urlopen(safeAdd)
data = BeautifulSoup(html, 'html.parser')



table = data.find("table",{"class" : "data-table block-wide"})
rows = table.findAll("tr",limit=17)

hasil = []
for row in rows:
    info = []
    for cell in row.findAll(["td","th"]):
        info.append(cell.get_text().strip())
    hasil.append(info)



# print(hasil)
df = pd.DataFrame(hasil[1:],columns = hasil[0])
df.set_index('#', inplace=True)

# %%
df
# Out:
#                            Name          Type Total  HP Attack Defense  \
# #
# 001                   Bulbasaur  Grass Poison   318  45     49      49
# 002                     Ivysaur  Grass Poison   405  60     62      63
# 003                    Venusaur  Grass Poison   525  80     82      83
# 003      Venusaur Mega Venusaur  Grass Poison   625  80    100     123
# 004                  Charmander          Fire   309  39     52      43
# 005                  Charmeleon          Fire   405  58     64      58
# 006                   Charizard   Fire Flying   534  78     84      78
# 006  Charizard Mega Charizard X   Fire Dragon   634  78    130     111
# 006  Charizard Mega Charizard Y   Fire Flying   634  78    104      78
# 007                    Squirtle         Water   314  44     48      65
# 008                   Wartortle         Water   405  59     63      80
# 009                   Blastoise         Water   530  79     83     100
# 009    Blastoise Mega Blastoise         Water   630  79    103     120
# 010                    Caterpie           Bug   195  45     30      35
# 011                     Metapod           Bug   205  50     20      55
# 012                  Butterfree    Bug Flying   395  60     45      50
#
#     Sp. Atk Sp. Def Speed
# #
# 001      65      65    45
# 002      80      80    60
# 003     100     100    80
# 003     122     120    80
# 004      60      50    65
# 005      80      65    80
# 006     109      85   100
# 006     130      85   100
# 006     159     115   100
# 007      50      64    43
# 008      65      80    58
# 009      85     105    78
# 009     135     115    78
# 010      20      20    45
# 011      25      25    30
# 012      90      80    70

# %%
df.to_excel("TugasPythonLanjutan_Hari_10_MuhammadFaishalDarmaPutra.xlsx") #df bisa diganti nama dataframe
